# %% [markdown]
# # Data analysis using Pandas
#
# dataset [link](https://drive.google.com/file/d/1pm7jxMDg4EXQaFlFqKS2f2XcT-blVzo3/view?usp=sharing)
# * Data series
# * File I/O
# * Indexing
# * Grouping
# * Features
# * Filtering
# * Sorting
# * Statistical
# * Plotting
# * Saving

# %%
import pandas as pd

# %%
# excel into dataframe
df = pd.read_excel("2020-08-27.xlsx")
df
# Out:
#       Roll number                                      College Name   \
# 0      17KD1A0587     Lendi Institute of Engineering and Technology
# 1    317126510088  Anil Neerukonda Institute of Technology & Scie...
# 2         S160783  Rajiv Gandhi University of Knowledge Technolog...
# 3      17691A04M9    Madanapalle institute of technology and science
# 4         S160323  RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES
# ..            ...                                                ...
# 245    18B91A0478          Sagi Ramakrishna raju engineering college
# 246    18B91A0427                     Sagi Ramakrishnam Raju college
# 247    15NE1A0466                      Tirumala engineering college
# 248    16FE1F0014      Vignan lara institute of technology & science
# 249     18B91A025        Sagi Rama Krishnam Raju Engineering College
#
#           Name ( As per SSC)                       Email Id
# 0           Mandapati Likitha        likitham1103@gmail.com
# ...

# %%
df.head() # first 5 student list
# Out:
#     Roll number                                      College Name   \
# 0    17KD1A0587     Lendi Institute of Engineering and Technology
# 1  317126510088  Anil Neerukonda Institute of Technology & Scie...
# 2       S160783  Rajiv Gandhi University of Knowledge Technolog...
# 3    17691A04M9    Madanapalle institute of technology and science
# 4       S160323  RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES
#
#         Name ( As per SSC)                       Email Id
# 0         Mandapati Likitha        likitham1103@gmail.com
# 1  Kuppili sai pavan sekhar       K.pavansai900@gmail.com
# 2      Vegi Saigirijakumari  saigirijakumari783@gmail.com
# 3   Kanam Palli Venu Madhav         17691a04m9@mits.ac.in
# 4      ALLU VENKATA SIVASAI       s160323@rguktsklm.ac.in

# %%
df.tail(6) # last 6 student list
# Out:
#     Roll number                                      College Name   \
# 244  14HP1D3805  Andhra loyola institute of engineering and tec...
# 245  18B91A0478          Sagi Ramakrishna raju engineering college
# 246  18B91A0427                     Sagi Ramakrishnam Raju college
# 247  15NE1A0466                      Tirumala engineering college
# 248  16FE1F0014      Vignan lara institute of technology & science
# 249   18B91A025        Sagi Rama Krishnam Raju Engineering College
#
#         Name ( As per SSC)                     Email Id
# 244             Shaik nazma         Nazmask97@gmail.com
# 245    Kadali. Hari Krishna     harikadali789@gmail.com
# 246         Chaganti Nikhil  chagantinikhil22@gmail.com
# 247         Kosaraju Akhila   Kosarajuakhila7@gmail.com
# 248        Gangasani Anusha    anugangasani33@gmail.com
# 249  Buddana L Sai Subhakar   buddanasubhakar@gmail.com

# %%
df.sample(3) # 1 random selection
# Out:
#     Roll number                                      College Name   \
# 17   17131A0210  Gayatri vidya Parishad college of engineering (A)
# 221  18F21A04B7                      GATES INSTITUTE OF TECHNOLOGY
# 97   17HP1A0443  ANDHRA LOYOLA INSTITUTE OF ENGINEERING AND TEC...
#
#            Name ( As per SSC)                       Email Id
# 17             Bandaru saritha   bandarusaritha093@gmail.com
# 221           PERAM SAI GANESH      ganeshgana5712@gmail.com
# 97   SRIKHAKOLANU  NAGA VENKAT  nagavenkat19111999@gmail.com

# %% [markdown]
# # Indexing

# %%
df[100:101] # getting particular person
# Out:
#     Roll number                                      College Name   \
# 100     N110046  Rajiv Gandhi University of knowledge technolog...
#
#     Name ( As per SSC)                 Email Id
# 100        PERLA RAJESH  rajesh953157@gmail.com

# %%
df.shape  # rows,columns
# Out:
# (250, 4)

# %%
df.columns
# Out:
# Index(['Roll number', 'College Name ', 'Name ( As per SSC) ', 'Email Id'], dtype='object')

# %%
df[100:200:10]  # start,end,step
# Out:
#      Roll number                                      College Name   \
# 100      N110046  Rajiv Gandhi University of knowledge technolog...
# 110   179X1A03H0                  G Pulla Reddy Engineering College
# 120   14f95a0504                      Prakasam engineering college
# 130      1775033               Sri Padmavati Mahila Visvavidyalayam
# 140    Y17cs2623               Bapatla women's engineering college
# 150   16191A0328           Jntua college of engineering pulivendula
# 160  17KD1A0586    Lendi institution of engineering and technology
# 170   183J1A0593                      Raghu Institute of Technology
# 180   17341A0458                        GMR INSTITUTE OF TECHNOLOGY
# 190   171FA04319  Vignan's foundation for science technology and...
#
#        Name ( As per SSC)                             Email Id
# 100           PERLA RAJESH              rajesh953157@gmail.com
# 110  Yenduri RameshChandra            yenduriramesh9@gmail.com
# ...

# %%
df[1:2] # row indexing
# Out:
#     Roll number                                      College Name   \
# 1  317126510088  Anil Neerukonda Institute of Technology & Scie...
#
#         Name ( As per SSC)                  Email Id
# 1  Kuppili sai pavan sekhar  K.pavansai900@gmail.com

# %%
# column indexing
df["Roll number"]
# Out:
# 0        17KD1A0587
# 1      317126510088
# 2           S160783
# 3        17691A04M9
# 4           S160323
#            ...
# 245      18B91A0478
# 246      18B91A0427
# 247      15NE1A0466
# 248      16FE1F0014
# 249       18B91A025
# Name: Roll number, Length: 250, dtype: object

# %%
df["Roll number"][245]
# Out:
# '18B91A0478'

# %%
df[["Roll number","Email Id"]] # accessing multiple columns -  sub df
# Out:
#       Roll number                      Email Id
# 0      17KD1A0587        likitham1103@gmail.com
# 1    317126510088       K.pavansai900@gmail.com
# 2         S160783  saigirijakumari783@gmail.com
# 3      17691A04M9         17691a04m9@mits.ac.in
# 4         S160323       s160323@rguktsklm.ac.in
# ..            ...                           ...
# 245    18B91A0478       harikadali789@gmail.com
# 246    18B91A0427    chagantinikhil22@gmail.com
# 247    15NE1A0466     Kosarajuakhila7@gmail.com
# 248    16FE1F0014      anugangasani33@gmail.com
# 249     18B91A025     buddanasubhakar@gmail.com
#
# [250 rows x 2 columns]

# %%
df.loc[100:200:20]
# Out:
#      Roll number                                      College Name   \
# 100      N110046  Rajiv Gandhi University of knowledge technolog...
# 120   14f95a0504                      Prakasam engineering college
# 140    Y17cs2623               Bapatla women's engineering college
# 160  17KD1A0586    Lendi institution of engineering and technology
# 180   17341A0458                        GMR INSTITUTE OF TECHNOLOGY
# 200   183T1A0523          Ravindra college of engineering for women
#
#        Name ( As per SSC)                             Email Id
# 100           PERLA RAJESH              rajesh953157@gmail.com
# 120             Nagaraju M               mnr.naidu91@gmail.com
# 140  Cherukupalli Ramadevi  ramadevicherukupalli8362@gmail.com
# 160    Mandala Vijay Kumar          vijaymandala1943@gmail.com
# 180          GARA NIHARIKA            niharika.gara7@gmail.com
# 200   chaduvula chihenitha                 chikisiva@gmail.com

# %%
dff = df.set_index("Roll number")
dff
# Out:
#                                                   College Name   \
# Roll number
# 17KD1A0587       Lendi Institute of Engineering and Technology
# 317126510088  Anil Neerukonda Institute of Technology & Scie...
# S160783       Rajiv Gandhi University of Knowledge Technolog...
# 17691A04M9      Madanapalle institute of technology and science
# S160323       RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES
# ...                                                         ...
# 18B91A0478            Sagi Ramakrishna raju engineering college
# 18B91A0427                       Sagi Ramakrishnam Raju college
# 15NE1A0466                        Tirumala engineering college
# 16FE1F0014        Vignan lara institute of technology & science
# 18B91A025           Sagi Rama Krishnam Raju Engineering College
#
#                    Name ( As per SSC)                       Email Id
# Roll number
# 17KD1A0587           Mandapati Likitha        likitham1103@gmail.com
# ...

# %%
dff.head()
# Out:
#                                                   College Name   \
# Roll number
# 17KD1A0587       Lendi Institute of Engineering and Technology
# 317126510088  Anil Neerukonda Institute of Technology & Scie...
# S160783       Rajiv Gandhi University of Knowledge Technolog...
# 17691A04M9      Madanapalle institute of technology and science
# S160323       RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES
#
#                    Name ( As per SSC)                       Email Id
# Roll number
# 17KD1A0587           Mandapati Likitha        likitham1103@gmail.com
# 317126510088  Kuppili sai pavan sekhar       K.pavansai900@gmail.com
# S160783           Vegi Saigirijakumari  saigirijakumari783@gmail.com
# 17691A04M9     Kanam Palli Venu Madhav         17691a04m9@mits.ac.in
# S160323           ALLU VENKATA SIVASAI       s160323@rguktsklm.ac.in

# %%
df.columns
# Out:
# Index(['Roll number', 'College Name ', 'Name ( As per SSC) ', 'Email Id'], dtype='object')

# %%
type(df["Name ( As per SSC) "])  # it returns series object
# Out:
# pandas.core.series.Series

# %%
dff[["Name ( As per SSC) "]]
# Out:
#                    Name ( As per SSC)
# Roll number
# 17KD1A0587           Mandapati Likitha
# 317126510088  Kuppili sai pavan sekhar
# S160783           Vegi Saigirijakumari
# 17691A04M9     Kanam Palli Venu Madhav
# S160323           ALLU VENKATA SIVASAI
# ...                                ...
# 18B91A0478        Kadali. Hari Krishna
# 18B91A0427             Chaganti Nikhil
# 15NE1A0466             Kosaraju Akhila
# 16FE1F0014            Gangasani Anusha
# 18B91A025       Buddana L Sai Subhakar
#
# [250 rows x 1 columns]

# %% [markdown]
# iloc and loc
# iloc -- integer row indexing  # intergers
# loc - label/columns indexing  # intergers and string objects

# %%
dff.loc["17HP1A0443"]
# Out:
# College Name           ANDHRA LOYOLA INSTITUTE OF ENGINEERING AND TEC...
# Name ( As per SSC)                             SRIKHAKOLANU  NAGA VENKAT
# Email Id                                    nagavenkat19111999@gmail.com
# Name: 17HP1A0443, dtype: object

# %%
dff.loc["17HP1A0443","Email Id"]
# Out:
# 'nagavenkat19111999@gmail.com'

# %%
dff.loc["17NU1A0533 "]
# Out:
# College Name           NADIMPALLI SATYANARAYANA RAJU INSTITUTE OF TEC...
# Name ( As per SSC)                                  NAMBURI NIKHIL VARMA
# Email Id                                    nikhilvarmanamburi@gmail.com
# Name: 17NU1A0533 , dtype: object

# %%
dff.loc[["17HP1A0443","17691A04M9"],"Email Id"]
# Out:
# Roll number
# 17HP1A0443    nagavenkat19111999@gmail.com
# 17691A04M9           17691a04m9@mits.ac.in
# Name: Email Id, dtype: object

# %%
list(dff.index)
# Out:
# ['17KD1A0587',
#  '317126510088',
#  'S160783',
#  '17691A04M9',
#  'S160323',
#  '183J1A0543',
#  '15FE1A0408',
#  'Y17CS3206',
#  '16NE1A0549',
#  '1775013',
#  '18G01A0564',
#  '17HP1A0583',
#  'S160592',
#  '179X1A04A8',
#  '17JG1A0502',
#  '318114110011',
#  '19B81A0212',
#  '17131A0210',
#  '17NM1A05C8',
#  '317114110011(regular)',
#  '17F21A0423',
#  '166C1A0537',
#  '188W1A12B4',
#  '18JR1A05D5',
#  '17NM1A04D9',
#  '17NN1A05C9',
#  '17B81A0218',
#  '18kf1a0454',
#  '171FA04492',
#  '171FA04496',
#  '18PC5A0314',
#  '16PA1A05B4',
#  '18691A0117',
#  '18225A0347',
#  '17x51a0406',
#  '163H1A0526',
#  '17x51a0419 ',
#  '17BQ1A0448',
#  '19KD1A1513',
#  '18JN5A0507',
#  '17761A0456',
#  '18NM1A0578',
#  '18091A04H0',
#  '17KD1A0243',
#  '17F21A0418',
#  '13U41A0420',
#  '171FA04511',
#  '18VV5A0567',
#  '319114110014',
#  '182610560',
#  '181FA04483',
#  '17BQ5A0405',
#  '17JK1A0434',
#  '17BC1A0550',
#  '18A31A0516',
#  '16AJ1A05A9',
#  '16Q71A0593',
#  '16A51A0451',
# ...

# %% [markdown]
# # Grouping

# %%
data = pd.read_csv("bird.csv")
data.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
data["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
data.shape
# Out:
# (420, 12)

# %%
data["type"].unique()
# Out:
# array(['SW', 'W', 'T', 'R', 'P', 'SO'], dtype=object)

# %%
g_data = data.groupby("type")
g_data

# %%
for name,group in g_data:
    print(name,group)
# Out:
# P       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_data.get_group("P")
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 254  254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# 255  255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# 256  256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# 257  257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# 258  258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
# 259  259  43.97  3.54  38.38   3.14  52.49  4.25  83.15  4.12  61.08  3.04
# 260  260  46.38  3.41  39.80   3.48  54.67  4.08  85.88  4.04  63.75  3.09
# 261  261  45.57  4.64  57.13   2.93  28.32  2.26  36.95  1.96  19.75  2.16
# 262  262  33.81  2.80  42.82   2.22  18.88  1.45  26.28  1.31  14.45  1.29
# 263  263  31.72  2.64  40.00   1.99  20.36  1.59  32.21  1.62  17.72  1.52
# 264  264   9.85  2.88  14.73   1.73  16.27  1.22  20.89  1.25   7.77  1.23
# ...

# %%
g_data.first()  # getting first record of every group
# Out:
#        id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw    tarl  \
# type
# P     254   29.26  2.66   27.63   2.23  27.87  2.03   38.90  1.81   25.22
# R     204   63.76  4.74   69.06   4.08  57.33  4.88   75.67  4.33   60.19
# SO    292   29.61  2.41   33.93   2.02  30.79  2.19   51.64  2.01   37.33
# SW      0   80.78  6.68   72.01   4.88  41.81  3.70    5.50  4.03   38.70
# T     181   43.97  4.64   51.07   3.80  38.76  3.18   55.67  2.88   30.41
# W     116  157.00  9.00  192.00   7.02  85.60  6.44  227.00  6.84  175.00
#
#       tarw
# type
# P     1.62
# R     3.82
# SO    1.78
# SW    3.84
# T     2.83
# W     6.77

# %%
g_data.last() # last i=one record of every group
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
# R     253  35.63  2.40  42.67   2.02  28.51  2.41  42.64  2.46  21.05  3.12
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
# SW    115  98.73  6.48  91.69   5.31  35.34  4.02  92.36  4.46  50.53  2.69
# T     203  39.64  4.07  37.32   2.98  45.50  3.42  64.45  3.37  37.77  2.86
# W     180  87.01  5.18  94.34   4.45  35.73  2.80  67.12  2.93  43.43  2.34

# %%
g_data.tail()
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 111  111  106.23   6.82  104.02   5.07   40.06   4.96  105.34   4.99   57.27
# 112  112  105.19   7.10   96.85   5.43   37.61   4.43  102.04   4.90   54.78
# 113  113   76.49   5.36   69.06   4.02   30.07   3.03   72.41   3.71   43.11
# 114  114   65.66   3.79   61.06   3.35   24.95   2.44   63.76   2.72   40.19
# 115  115   98.73   6.48   91.69   5.31   35.34   4.02   92.36   4.46   50.53
# 176  176   33.20   2.11   34.31   2.25   20.36   1.57   37.95   1.42   23.67
# 177  177   32.31   2.16   32.74   1.98   19.05   1.40   33.37   1.14   21.20
# 178  178   28.51   1.80   29.35   1.78   17.60   1.21   36.04   1.14   20.81
# 179  179   34.12   1.90   35.57   1.93   21.22   1.39   46.24   1.27   31.39
# 180  180   87.01   5.18   94.34   4.45   35.73   2.80   67.12   2.93   43.43
# 199  199   32.68   3.26   29.02   2.36   39.38   2.72   56.45   2.50   32.56
# ...

# %%
help(data.groupby)
# Out:
# Help on method groupby in module pandas.core.frame:
#
# groupby(by=None, axis=0, level=None, as_index: bool = True, sort: bool = True, group_keys: bool = True, squeeze: bool = False, observed: bool = False) -> 'groupby_generic.DataFrameGroupBy' method of pandas.core.frame.DataFrame instance
#     Group DataFrame using a mapper or by a Series of columns.
#
#     A groupby operation involves some combination of splitting the
#     object, applying a function, and combining the results. This can be
#     used to group large amounts of data and compute operations on these
#     groups.
#
#     Parameters
#     ----------
#     by : mapping, function, label, or list of labels
#         Used to determine the groups for the groupby.
#         If ``by`` is a function, it's called on each value of the object's
#         index. If a dict or Series is passed, the Series or dict VALUES
#         will be used to determine the groups (the Series' values are first
# ...

# %% [markdown]
# # Features

# %%
labels/ entries 
numerical / objects

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      420 non-null    int64
#  1   huml    419 non-null    float64
#  2   humw    419 non-null    float64
#  3   ulnal   417 non-null    float64
#  4   ulnaw   418 non-null    float64
#  5   feml    418 non-null    float64
#  6   femw    419 non-null    float64
#  7   tibl    418 non-null    float64
#  8   tibw    419 non-null    float64
#  9   tarl    419 non-null    float64
#  10  tarw    419 non-null    float64
#  11  type    420 non-null    object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 39.5+ KB

# %%
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ...

# %%
data["type_len"] = data["type"]

# %%
data["type"].str.len()
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 415    2
# 416    2
# 417    2
# 418    2
# 419    2
# Name: type, Length: 420, dtype: int64

# %%
data["type"]
# Out:
# 0      SW
# 1      SW
# 2      SW
# 3      SW
# 4      SW
#        ..
# 415    SO
# 416    SO
# 417    SO
# 418    SO
# 419    SO
# Name: type, Length: 420, dtype: object

# %%
data["type_len"] = data["type"].str.len()
data
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type  type_len
# 0     SW         2
# 1     SW         2
# ...

# %% [markdown]
# # Filtering

# %%
df.columns
# Out:
# Index(['Roll number', 'College Name ', 'Name ( As per SSC) ', 'Email Id'], dtype='object')

# %%
df["Roll number"] == "17KD1A0587"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Name: Roll number, Length: 250, dtype: bool

# %%
df[df["Roll number"] == "17KD1A0587"]
# Out:
#   Roll number                                   College Name   \
# 0  17KD1A0587  Lendi Institute of Engineering and Technology
#
#   Name ( As per SSC)                 Email Id
# 0   Mandapati Likitha  likitham1103@gmail.com

# %%
df.head()
# Out:
#     Roll number                                      College Name   \
# 0    17KD1A0587     Lendi Institute of Engineering and Technology
# 1  317126510088  Anil Neerukonda Institute of Technology & Scie...
# 2       S160783  Rajiv Gandhi University of Knowledge Technolog...
# 3    17691A04M9    Madanapalle institute of technology and science
# 4       S160323  RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES
#
#         Name ( As per SSC)                       Email Id
# 0         Mandapati Likitha        likitham1103@gmail.com
# 1  Kuppili sai pavan sekhar       K.pavansai900@gmail.com
# 2      Vegi Saigirijakumari  saigirijakumari783@gmail.com
# 3   Kanam Palli Venu Madhav         17691a04m9@mits.ac.in
# 4      ALLU VENKATA SIVASAI       s160323@rguktsklm.ac.in

# %%
df[df["Roll number"] == "18005A0208"]
# Out:
#     Roll number                                      College Name   \
# 163  18005A0208  Jawaharlal Nehru technological University Anan...
# 164  18005A0208  Jawaharlal Nehru technological University Anan...
#
#            Name ( As per SSC)                    Email Id
# 163  NOSSAM SHAIK AHAMAD BASHA  ahammedbasha950@gmail.com
# 164  NOSSAM SHAIK AHAMAD BASHA  ahammedbasha950@gmail.com

# %%
df[(df["Roll number"] == "18005A0208") | ('Name ( As per SSC) ' == "NOSSAM SHAIK AHAMAD BASHA")]
# Out:
#     Roll number                                      College Name   \
# 163  18005A0208  Jawaharlal Nehru technological University Anan...
# 164  18005A0208  Jawaharlal Nehru technological University Anan...
#
#            Name ( As per SSC)                    Email Id
# 163  NOSSAM SHAIK AHAMAD BASHA  ahammedbasha950@gmail.com
# 164  NOSSAM SHAIK AHAMAD BASHA  ahammedbasha950@gmail.com

# %% [markdown]
# # Sorting

# %%
data.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type  \
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW
#
#    type_len
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2

# %%
data.sort_index(axis = 1,ascending=True).head()
# Out:
#     feml  femw   huml  humw  id   tarl  tarw   tibl  tibw type  type_len  \
# 0  41.81  3.70  80.78  6.68   0  38.70  3.84   5.50  4.03   SW         2
# 1  47.04  4.30  88.91  6.63   1  41.50  4.01  80.22  4.51   SW         2
# 2  43.07  3.90  79.97  6.37   2  38.31  3.34  75.35  4.04   SW         2
# 3  40.04  3.52  77.65  5.70   3  35.78  3.41  69.17  3.40   SW         2
# 4  33.95  2.72  62.80  4.84   4  31.88  3.13  56.27  2.96   SW         2
#
#    ulnal  ulnaw
# 0  72.01   4.88
# 1  80.53   5.59
# 2  69.26   5.28
# 3  65.76   4.77
# 4  52.09   3.73

# %%
data.sort_index(axis = 1,ascending=False).head()
# Out:
#    ulnaw  ulnal  type_len type  tibw   tibl  tarw   tarl  id  humw   huml  \
# 0   4.88  72.01         2   SW  4.03   5.50  3.84  38.70   0  6.68  80.78
# 1   5.59  80.53         2   SW  4.51  80.22  4.01  41.50   1  6.63  88.91
# 2   5.28  69.26         2   SW  4.04  75.35  3.34  38.31   2  6.37  79.97
# 3   4.77  65.76         2   SW  3.40  69.17  3.41  35.78   3  5.70  77.65
# 4   3.73  52.09         2   SW  2.96  56.27  3.13  31.88   4  4.84  62.80
#
#    femw   feml
# 0  3.70  41.81
# 1  4.30  47.04
# 2  3.90  43.07
# 3  3.52  40.04
# 4  2.72  33.95

# %%
data.sort_values(by = "feml")
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 377  377   12.69   1.69   17.44   1.16   11.83   1.03   23.80   0.87   16.97
# 70    70   26.63   1.63   27.19   1.72   12.21   1.02   31.56   1.07   21.62
# 367  367   13.31   1.17   16.47   1.06   12.32   0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48   1.12   24.91   0.92   17.55
# 71    71   26.81   1.66   26.48   1.51   12.54   0.97   31.55   1.01   21.17
# ..   ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 201  201  118.75  11.90  104.68   4.77  108.85  10.29  183.00   9.69  134.00
# 58    58  420.00  17.84  422.00  11.72  110.54   9.99  237.00  11.03  128.35
# 202  202  127.00  13.79  123.27   9.42  117.07  11.64  189.00  10.03  128.50
# 160  160   76.43   4.11   86.79   3.84     NaN    NaN   67.13   2.48   41.65
# 404  404   20.36   1.87   22.19   1.60     NaN   1.77   37.47   1.64   25.54
#
#      tarw type  type_len
# ...

# %%
data.sort_values(by = ["feml","huml"],ascending=True)
# Out:
#       id    huml   humw   ulnal  ulnaw    feml   femw    tibl   tibw    tarl  \
# 377  377   12.69   1.69   17.44   1.16   11.83   1.03   23.80   0.87   16.97
# 70    70   26.63   1.63   27.19   1.72   12.21   1.02   31.56   1.07   21.62
# 367  367   13.31   1.17   16.47   1.06   12.32   0.93   22.47   0.95   15.97
# 370  370   13.38   1.14   16.51   1.23   12.48   1.12   24.91   0.92   17.55
# 71    71   26.81   1.66   26.48   1.51   12.54   0.97   31.55   1.01   21.17
# ..   ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 201  201  118.75  11.90  104.68   4.77  108.85  10.29  183.00   9.69  134.00
# 58    58  420.00  17.84  422.00  11.72  110.54   9.99  237.00  11.03  128.35
# 202  202  127.00  13.79  123.27   9.42  117.07  11.64  189.00  10.03  128.50
# 404  404   20.36   1.87   22.19   1.60     NaN   1.77   37.47   1.64   25.54
# 160  160   76.43   4.11   86.79   3.84     NaN    NaN   67.13   2.48   41.65
#
#      tarw type  type_len
# ...

# %% [markdown]
# # Statistics

# %%
data["huml"].mean()
# Out:
# 64.6505011933174

# %%
data["feml"].median()
# Out:
# 31.130000000000003

# %%
data["type"].mode()
# Out:
# 0    SO
# dtype: object

# %%
data["type"].value_counts()
# Out:
# SO    128
# SW    116
# W      65
# R      50
# P      38
# T      23
# Name: type, dtype: int64

# %%
data["huml"].sum()
# Out:
# 27088.56

# %%
data["huml"].std()
# Out:
# 53.834548915405946

# %%
data["huml"].describe()
# Out:
# count    419.000000
# mean      64.650501
# std       53.834549
# min        9.850000
# 25%       25.170000
# 50%       44.180000
# 75%       90.310000
# max      420.000000
# Name: huml, dtype: float64

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
data?

# %%
len(dir(pd))
# Out:
# 142

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
plt.show()

# %%
data["huml"].plot()
plt.show()

# %% [markdown]
# # Saving

# %%
data["huml"].max()
# Out:
# 420.0

# %%
data["huml"].min()
# Out:
# 9.85

# %%
s_data = data[(data["huml"] > 100) | data["huml"]<200]
type(s_data)
# Out:
# pandas.core.frame.DataFrame

# %%
s_data.to_csv("sorted_data.csv")  # exporting data

# %%
s_data.to_excel("sorted.xlsx")

# %% [markdown]
# # Cleaning data in Python
#
#
# * NaN : not a number -- special floating-point value
# * Working with duplicates and missing values
#     * isnull()
#     * notnull()
#     * dropna()
#     * fillna()
#     * replace()
# * Which values should be replaced with missing values based on data identifying and eliminating outliers
# * Dropping duplicate data

# %%
plt.scatter([1,2,3,30],[2,3,4,41])

# %%
adv = pd.read_csv("https://raw.githubusercontent.com/APSSDC-Data-Analysis/Data-Analysis-B3-Afternoon/master/D5_Analysis%26Preprocessing/Advertising.csv")
adv.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
adv.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
emp = pd.read_csv("https://raw.githubusercontent.com/APSSDC-Data-Analysis/Data-Analysis-B3-Afternoon/master/D5_Analysis%26Preprocessing/employe.csv")
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
emp.shape
# Out:
# (1000, 8)

# %%
emp.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
emp.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
emp["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"].isnull().sum()
# Out:
# 145

# %%
emp["Gender"].fillna("no Gender")
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    no Gender
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"].fillna("no Gender").isnull().sum()
# Out:
# 0

# %%
emp["Gender"].fillna(method = "pad") # filling null values by previous once
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"][994]
# Out:
# 'Male'

# %%
emp["Gender"].fillna(method = "bfill") # filling null value with next one
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
emp["Gender"].fillna(100)  # replaced by constant
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       100
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
import numpy as np
emp.replace(to_replace = np.nan, value = -1)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry      -1  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                    -1
# ...

# %%
emp.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
emp["Gender"].fillna("no Gender")
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#          ...
# 995    no Gender
# 996         Male
# 997         Male
# 998         Male
# 999         Male
# Name: Gender, Length: 1000, dtype: object
